# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
upstage_api_key = os.getenv('UPSTAGE_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')
ollama_api_key = os.getenv('OLLAMA_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}") 
else:
    print("OpenAI API Key not set, please set it in the .env file")
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:8]}")
else:
    print("Anthropic API Key not set, please set it in the .env file")
if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:8]}")
else:
    print("Google API Key not set (and this is optional)")
if upstage_api_key:
    print(f"Upstage API Key exists and begins {upstage_api_key[:3]}")
else:
    print("Upstage API Key not set (and this is optional)")
if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:10]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
if ollama_api_key:
    print(f"Ollama API Key exists and begins {ollama_api_key[:3]}")
else:
    print("Ollama API Key not set (and this is optional)")
if deepseek_api_key:
    print(f"Deepseek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("Deepseek API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-a
# Google API Key exists and begins AIzaSyAE
# Upstage API Key exists and begins up_
# OpenRouter API Key exists and begins sk-or-v1-c
# Ollama API Key not set (and this is optional)
# Deepseek API Key exists and begins sk-

# %%
openai=OpenAI()

anthropic_base_url = "https://api.anthropic.com/v1"
google_base_url = "https://generativelanguage.googleapis.com/v1beta3"
openrouter_base_url = "https://api.openrouter.ai/v1"
ollama_base_url = "http://localhost:11434/v1"
deepseek_base_url = "https://api.deepseek.com/v1"

claude=OpenAI(api_key=anthropic_api_key, base_url=anthropic_base_url)
gemini=OpenAI(api_key=google_api_key, base_url=google_base_url)
openrouter=OpenAI(api_key=openrouter_api_key, base_url=openrouter_base_url)
ollama=OpenAI(api_key=ollama_api_key, base_url=ollama_base_url)
deepseek=OpenAI(api_key=deepseek_api_key, base_url=deepseek_base_url)

# %%
question = "What is a business area that is worth exporing in the Agentic AI area?"
messages = [{"role": "user", "content": question}]

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=messages)
question = response.choices[0].message.content

display(Markdown(question))
# Out:
# Short answer: Autonomous Customer Success / Account Management agents for small-to-medium businesses (SMBs) — AI agents that autonomously manage onboarding, health monitoring, renewal/upsell outreach, and routine support tasks — is a high-potential business area to explore.
#
# Why this is attractive
# - Clear ROI: reducing churn and increasing expansions directly raise MRR/ARR and are easy to quantify for customers.
# - Large, fragmented market: millions of SMBs use SaaS products and CRMs but can’t afford large CSM teams.
# - Plenty of structured signals: product usage, billing, support tickets, and CRM records make agent decision-making tractable.
# - Natural fit for agentic capabilities: multi-step planning, tool use (calendar, email, ticketing), long-horizon follow-ups, and escalation to humans.
# - Lower regulatory risk than areas like clinical or legal advice.
#
# Concrete product concept
# - An "Account Health Agent" that:
# ...

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question + "Present a pain-point in that industry - something challenging that might be ripe for an Agentic solution. And present that AI Agentic solution "}]

# %%
model_name = "gpt-5-nano"
response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Vertical: SMB Shopify apps / e-commerce SaaS
#
# Pain-point
# - Onboarding churn and activation friction: new merchants sign up but struggle to configure essential automations (welcome series, order notifications, abandoned-cart flows), leading to slow time-to-value, higher support load, and higher early churn.
# - Limited CS bandwidth in SMBs means repetitive, high-volume outreach and follow-ups are impractical to do manually.
# - Fragmented signals (store events, billing, usage, support) make it hard for busy merchants to stay engaged and for teams to know which accounts need attention.
#
# AI Agentic solution: Account Health Agent for SMB e-commerce apps
#
# What it does
# - Ingests and synthesizes data from Shopify stores, billing (Stripe/Chargebee), product analytics (Segment/Amplitude), CRM (HubSpot/Salesforce), and helpdesk tickets.
# - Continuously scores account health (activation, feature adoption, billing status, support engagement, NPS).
# ...

# %%
model_name = "claude-sonnet-4-5"
response = claude.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)  
answers.append(answer)
# Out:
# # Pain Point: The "Scale Trap" in SaaS Customer Success
#
# ## The Problem
#
# **Mid-market SaaS companies (100–5,000 customers) hit a brutal economic wall:**
#
# - They have **too many accounts** to give white-glove treatment to all customers
# - But **too few customers** to justify a large, specialized CS team
# - **Result:** The bottom 60–80% of accounts get zero proactive attention
#
# ### What happens in practice:
#
# A typical Series A/B SaaS company with 800 customers might have:
# - 2–3 CSMs managing the top 50 enterprise accounts (hands-on)
# - **750 SMB/mid-market accounts that only hear from the company when:**
#   - Their credit card fails
#   - They open a support ticket
#   - It's renewal time (often automated email)
#
# ### Why this is painful:
#
# 📉 **Silent churn epidemic**
# - 15–30% of these "ignored" accounts quietly churn at renewal
# - Companies discover churn reasons *after* the customer left
# - No early warning system for declining engagement
#
# ...

# %%
upstage = OpenAI(api_key=upstage_api_key, base_url="https://api.upstage.ai/v1")

model_name = "solar-pro"
response = upstage.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ### **Industry: E-Commerce SaaS (e.g., Shopify App Providers, Payment Gateways, Fulfillment Platforms)**
#
# #### **Pain Point: "The Onboarding Abyss" & "Silent Churn"**
# E-commerce SMBs often sign up for SaaS tools (e.g., payment gateways, inventory management, email marketing) with high intent but **low follow-through**. Key challenges:
# - **Incomplete onboarding**: 60%+ of SMBs never fully configure the product, leading to underutilization.
# - **No usage signals until failure**: E-commerce tools are often "set-and-forget" until a critical issue (e.g., payment failure, inventory miscount) causes abrupt churn.
# - **No proactive health checks**: SMBs don’t have the bandwidth to monitor integrations, leading to hidden technical debt (e.g., API key expiration, broken webhooks).
# - **Upsell missed**: SMBs grow, but providers don’t know when to suggest add-ons (e.g., "You’re now processing $10K/month—try our advanced reporting").
#
# ...

# %%
groq_api_key = os.getenv('GROQ_API_KEY')


if groq_api_key:
    print(f"GROQ API Key exists and begins {groq_api_key[:3]}")
else:
    print("GROQ API Key not set (and this is optional)")
# Out:
# GROQ API Key exists and begins gsk

# %%
groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")

model_name = "qwen/qwen3-32b"
response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# <think>
# Okay, so the user wants an example of a pain-point in an industry that could be solved by an AI agent, along with the agentic solution. Let me think about industries where SMBs are struggling with customer success tasks without enough resources.
#
# First, the user mentioned SaaS tools, marketing platforms, and e-commerce platforms as potential verticals. Maybe pick one of those. Let's go with e-commerce since it's a big area with a lot of SMBs.
#
# What's a common pain point for e-commerce businesses? They need to manage customer churn, onboarding, support, etc. But they don't have large CSM teams. Maybe something specific like managing customer retention for online stores. Or maybe onboarding suppliers, but that might be more complex.
#
# ...

# %%
model_name = "gemma-4-26b-a4b-it"

gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content
display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# <thought>
# *   *Context:* The user provided a detailed business plan for "Autonomous Customer Success/Account Management agents for SMBs."
#     *   *Goal:* The user wants me to:
#         1.  Identify a specific, deep pain point within that industry (SMB Customer Success).
#         2.  Present a specific Agentic AI solution to solve that pain point.
#     *   *Constraints:* The solution should be "Agentic" (meaning it's not just a chatbot, but a system capable of reasoning, tool use, planning, and autonomous action).
#
#     *   *The "Scale" Problem:* SMBs have many customers but very few CSMs.
#     *   *The "Reactive" Problem:* CSMs only talk to customers when things break (support tickets) or when a renewal is due (too late).
#     *   *The "Data Silo" Problem:* Usage data is in Amplitude, billing in Stripe, conversations in Intercom, and CRM in HubSpot. Humans can't watch all these simultaneously 24/7.
# ...

# %%
print(competitors)
print(answers)
# Out:
# ['gpt-5-nano', 'claude-sonnet-4-5', 'solar-pro', 'qwen/qwen3-32b', 'gemma-4-26b-a4b-it']
# ...

# %%
# Print all answers together
for competitor, answer in zip(competitors, answers):
    print(f"Model: {competitor}\nAnswer: {answer}\n\n")
# Out:
# Model: gpt-5-nano
# Answer: Vertical: SMB Shopify apps / e-commerce SaaS
#
# Pain-point
# - Onboarding churn and activation friction: new merchants sign up but struggle to configure essential automations (welcome series, order notifications, abandoned-cart flows), leading to slow time-to-value, higher support load, and higher early churn.
# - Limited CS bandwidth in SMBs means repetitive, high-volume outreach and follow-ups are impractical to do manually.
# - Fragmented signals (store events, billing, usage, support) make it hard for busy merchants to stay engaged and for teams to know which accounts need attention.
#
# AI Agentic solution: Account Health Agent for SMB e-commerce apps
#
# What it does
# - Ingests and synthesizes data from Shopify stores, billing (Stripe/Chargebee), product analytics (Segment/Amplitude), CRM (HubSpot/Salesforce), and helpdesk tickets.
# - Continuously scores account health (activation, feature adoption, billing status, support engagement, NPS).
# ...

# %%
together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# Vertical: SMB Shopify apps / e-commerce SaaS
#
# Pain-point
# - Onboarding churn and activation friction: new merchants sign up but struggle to configure essential automations (welcome series, order notifications, abandoned-cart flows), leading to slow time-to-value, higher support load, and higher early churn.
# - Limited CS bandwidth in SMBs means repetitive, high-volume outreach and follow-ups are impractical to do manually.
# - Fragmented signals (store events, billing, usage, support) make it hard for busy merchants to stay engaged and for teams to know which accounts need attention.
#
# AI Agentic solution: Account Health Agent for SMB e-commerce apps
#
# What it does
# - Ingests and synthesizes data from Shopify stores, billing (Stripe/Chargebee), product analytics (Segment/Amplitude), CRM (HubSpot/Salesforce), and helpdesk tickets.
# - Continuously scores account health (activation, feature adoption, billing status, support engagement, NPS).
# ...

# %%
import json

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(f"Judge prompt length: {len(judge)} characters")
print(f"Approximate tokens: {len(judge)//4}")
# Out:
# Judge prompt length: 40684 characters
# Approximate tokens: 10171

# %%
print(f"Number of competitors: {len(competitors)}")
print(f"Number of answers: {len(answers)}")
for i, answer in enumerate(answers):
    print(f"Answer {i+1} length: {len(answer)} characters")
# Out:
# Number of competitors: 5
# Number of answers: 5
# Answer 1 length: 6830 characters
# Answer 2 length: 9358 characters
# Answer 3 length: 4638 characters
# Answer 4 length: 6489 characters
# Answer 5 length: 8094 characters

# %%
judge_message = [{"role": "user", "content": judge}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_message,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["2", "1", "5", "3", "4"]}

# %%
print(f"Results: '{results}'")
print(f"Type: {type(results)}")
print(f"Length: {len(results)}")
# Out:
# Results: '{"results": ["2", "1", "5", "3", "4"]}'
# Type: <class 'str'>
# Length: 38

# %%
results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: claude-sonnet-4-5
# Rank 2: gpt-5-nano
# Rank 3: gemma-4-26b-a4b-it
# Rank 4: solar-pro
# Rank 5: qwen/qwen3-32b
